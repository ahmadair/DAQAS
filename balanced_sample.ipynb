# %% [markdown]
# # The determinants of early childhood education services provision

# %% [markdown]
# ### Use of resampling to balance the data

# %%
import pandas as pd
import sklearn
from sklearn.linear_model import LogisticRegression # LogisticRegression Package
import matplotlib.pyplot as plt # For visualization
import numpy as np 

import seaborn as sns # To visualize the count table
sns.set(style="white") # Options for sns
sns.set(style="whitegrid", color_codes=True) # Options for sns

# %% [markdown]
# The research question is what are the determinants of the provision of early childhood education services.

# %% [markdown]
# In this example we are using "Data Science Training Program Dataset1 - CommonCore".

# %% [markdown]
# First import the "CCD_Dataset" sheet from the excel file.
# You can replace the file_path with the pathname on your local disk.

# %%
# Import the data from local disc
file_path = "Data Science Training Program Dataset1 - CommonCore.xlsx"
df = pd.read_excel(file_path, sheet_name='CCD_Dataset')

# %%
df
# Out:
#          LEAID                                           LEA_NAME  ST_NAME  \
# 0       100002                             Alabama Youth Services  ALABAMA
# 1       100005                                   Albertville City  ALABAMA
# 2       100006                                    Marshall County  ALABAMA
# 3       100007                                        Hoover City  ALABAMA
# 4       100008                                       Madison City  ALABAMA
# ...        ...                                                ...      ...
# 16724  5680250                                     Region V BOCES  WYOMING
# 16725  5680251              Wyoming Department of Family Services  WYOMING
# 16726  5680252  Youth Emergency Services Inc. - Administration...  WYOMING
# 16727  5680254         Saint Stephen's Indian School Admin Office  WYOMING
# 16728  5680255                                    Rite of Passage  WYOMING
#
#        ST         COUNTY_NM  COUNTY_NO  NUM_SCHS  NUM_CHRTS  \
# 0      AL  Jefferson County       1073         0          0
# 1      AL   Marshall County       1095         6          0
# 2      AL   Marshall County       1095        15          0
# 3      AL  Jefferson County       1073        17          0
# 4      AL    Madison County       1089        11          0
# ...    ..               ...        ...       ...        ...
# 16724  WY      Teton County      56039         1          0
# 16725  WY    Laramie County      56021         2          0
# 16726  WY   Campbell County      56005         1          0
# 16727  WY    Fremont County      56013         1          0
# 16728  WY    Douglas County      32005         1          0
#
#                                                     TYPE  LEP  ...  \
# 0                             8-Other education agencies   -1  ...
# 1      1-Regular local school district that is NOT a ...  929  ...
# 2      1-Regular local school district that is NOT a ...  394  ...
# 3      1-Regular local school district that is NOT a ...  760  ...
# 4      1-Regular local school district that is NOT a ...  364  ...
# ...                                                  ...  ...  ...
# 16724  5-State agency providing elementary and/or sec...   -1  ...
# 16725  5-State agency providing elementary and/or sec...   -1  ...
# 16726  5-State agency providing elementary and/or sec...   -1  ...
# 16727  5-State agency providing elementary and/or sec...   -1  ...
# 16728  5-State agency providing elementary and/or sec...   -1  ...
#
#        LEA_DISTEDENR_WH_M  LEA_DISTEDENR_WH_F  LEA_DISTEDENR_TR_M  \
# 0                      -9                  -9                  -9
# 1                       2                   9                   0
# 2                      45                  52                   0
# 3                     130                 240                   9
# 4                      59                 107                   2
# ...                   ...                 ...                 ...
# 16724                  -9                  -9                  -9
# 16725                  -9                  -9                  -9
# 16726                  -9                  -9                  -9
# 16727                   0                   0                   0
# 16728                  -9                  -9                  -9
#
#        LEA_DISTEDENR_TR_F  TOT_DISTEDENR_M TOT_DISTEDENR_F  \
# 0                      -9               -9              -9
# 1                       0                4              14
# 2                       0               64              75
# 3                      12              218             340
# 4                       1               89             154
# ...                   ...              ...             ...
# 16724                  -9               -9              -9
# 16725                  -9               -9              -9
# 16726                  -9               -9              -9
# 16727                   0                0               1
# 16728                  -9               -9              -9
#
#        LEA_DISTEDENR_LEP_M  LEA_DISTEDENR_LEP_F  LEA_DISTEDENR_IDEA_M  \
# 0                       -9                   -9                    -9
# 1                        0                    0                     0
# 2                        0                    0                     3
# 3                       18                   28                    28
# 4                        2                    4                     1
# ...                    ...                  ...                   ...
# 16724                   -9                   -9                    -9
# 16725                   -9                   -9                    -9
# 16726                   -9                   -9                    -9
# 16727                    0                    0                     0
# 16728                   -9                   -9                    -9
#
#        LEA_DISTEDENR_IDEA_F
# 0                        -9
# 1                         0
# 2                         2
# 3                         9
# 4                         2
# ...                     ...
# 16724                    -9
# 16725                    -9
# 16726                    -9
# 16727                     0
# 16728                    -9
#
# [16729 rows x 98 columns]

# %%
df = df.replace(dict.fromkeys([-1,-2,-9], np.NaN)) # Replacing missing -1, -2, -9 with missig values.
df = df.replace("Yes", 1) # Converting Yes or No values into numeric values of 1,0
df = df.replace("No",0)
df
# Out:
#          LEAID                                           LEA_NAME  ST_NAME  \
# 0       100002                             Alabama Youth Services  ALABAMA
# 1       100005                                   Albertville City  ALABAMA
# 2       100006                                    Marshall County  ALABAMA
# 3       100007                                        Hoover City  ALABAMA
# 4       100008                                       Madison City  ALABAMA
# ...        ...                                                ...      ...
# 16724  5680250                                     Region V BOCES  WYOMING
# 16725  5680251              Wyoming Department of Family Services  WYOMING
# 16726  5680252  Youth Emergency Services Inc. - Administration...  WYOMING
# 16727  5680254         Saint Stephen's Indian School Admin Office  WYOMING
# 16728  5680255                                    Rite of Passage  WYOMING
#
#        ST         COUNTY_NM  COUNTY_NO  NUM_SCHS  NUM_CHRTS  \
# 0      AL  Jefferson County       1073         0        0.0
# 1      AL   Marshall County       1095         6        0.0
# 2      AL   Marshall County       1095        15        0.0
# 3      AL  Jefferson County       1073        17        0.0
# 4      AL    Madison County       1089        11        0.0
# ...    ..               ...        ...       ...        ...
# 16724  WY      Teton County      56039         1        0.0
# 16725  WY    Laramie County      56021         2        0.0
# 16726  WY   Campbell County      56005         1        0.0
# 16727  WY    Fremont County      56013         1        0.0
# 16728  WY    Douglas County      32005         1        0.0
#
#                                                     TYPE    LEP  ...  \
# 0                             8-Other education agencies    NaN  ...
# 1      1-Regular local school district that is NOT a ...  929.0  ...
# 2      1-Regular local school district that is NOT a ...  394.0  ...
# 3      1-Regular local school district that is NOT a ...  760.0  ...
# 4      1-Regular local school district that is NOT a ...  364.0  ...
# ...                                                  ...    ...  ...
# 16724  5-State agency providing elementary and/or sec...    NaN  ...
# 16725  5-State agency providing elementary and/or sec...    NaN  ...
# 16726  5-State agency providing elementary and/or sec...    NaN  ...
# 16727  5-State agency providing elementary and/or sec...    NaN  ...
# 16728  5-State agency providing elementary and/or sec...    NaN  ...
#
#        LEA_DISTEDENR_WH_M  LEA_DISTEDENR_WH_F  LEA_DISTEDENR_TR_M  \
# 0                     NaN                 NaN                 NaN
# 1                     2.0                 9.0                 0.0
# 2                    45.0                52.0                 0.0
# 3                   130.0               240.0                 9.0
# 4                    59.0               107.0                 2.0
# ...                   ...                 ...                 ...
# 16724                 NaN                 NaN                 NaN
# 16725                 NaN                 NaN                 NaN
# 16726                 NaN                 NaN                 NaN
# 16727                 0.0                 0.0                 0.0
# 16728                 NaN                 NaN                 NaN
#
#        LEA_DISTEDENR_TR_F  TOT_DISTEDENR_M TOT_DISTEDENR_F  \
# 0                     NaN              NaN             NaN
# 1                     0.0              4.0            14.0
# 2                     0.0             64.0            75.0
# 3                    12.0            218.0           340.0
# 4                     1.0             89.0           154.0
# ...                   ...              ...             ...
# 16724                 NaN              NaN             NaN
# 16725                 NaN              NaN             NaN
# 16726                 NaN              NaN             NaN
# 16727                 0.0              0.0             1.0
# 16728                 NaN              NaN             NaN
#
#        LEA_DISTEDENR_LEP_M  LEA_DISTEDENR_LEP_F  LEA_DISTEDENR_IDEA_M  \
# 0                      NaN                  NaN                   NaN
# 1                      0.0                  0.0                   0.0
# 2                      0.0                  0.0                   3.0
# 3                     18.0                 28.0                  28.0
# 4                      2.0                  4.0                   1.0
# ...                    ...                  ...                   ...
# 16724                  NaN                  NaN                   NaN
# 16725                  NaN                  NaN                   NaN
# 16726                  NaN                  NaN                   NaN
# 16727                  0.0                  0.0                   0.0
# 16728                  NaN                  NaN                   NaN
#
#        LEA_DISTEDENR_IDEA_F
# 0                       NaN
# 1                       0.0
# 2                       2.0
# 3                       9.0
# 4                       2.0
# ...                     ...
# 16724                   NaN
# 16725                   NaN
# 16726                   NaN
# 16727                   0.0
# 16728                   NaN
#
# [16729 rows x 98 columns]

# %%
LEA = df['LEA_ECE_IND']
LEA.describe()
# Out:
# count    16729.000000
# mean         0.169227
# std          0.374964
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: LEA_ECE_IND, dtype: float64

# %%
print(LEA.unique())
print(LEA.value_counts())
# Out:
# [0 1]
# 0    13898
# 1     2831
# Name: LEA_ECE_IND, dtype: int64

# %%
df.columns
# Out:
# Index(['LEAID', 'LEA_NAME', 'ST_NAME', 'ST', 'COUNTY_NM', 'COUNTY_NO',
#        'NUM_SCHS', 'NUM_CHRTS', 'TYPE', 'LEP', 'IEP', 'TOTALREV', 'TOTALEXP',
#        'TOTALREVPP', 'TOTALEXPPP', 'LEVEL', 'MEMBER', 'AI_AN', 'AS_PI', 'HI',
#        'BL', 'WH', 'NH_OPI', 'TR', 'TOTETH', 'CJJ', 'LEA_ENR',
#        'LEA_ENR_NONLEAFAC', 'LEA_SCHOOLS', 'LEA_DESEGPLAN', 'LEA_HBPOLICY_IND',
#        'LEA_HBPOLICYURL_IND', 'LEA_HBPOLICY_URL', 'LEA_ECE_IND',
#        'LEA_ECE_NONIDEA', 'LEA_PS_IND', 'LEA_PS_FULLDAYFREE',
#        'LEA_PS_FULLDAYCOST', 'LEA_PS_PARTDAYFREE', 'LEA_PS_PARTDAYCOST',
#        'LEA_PSENR_NONIDEA_A3', 'LEA_PSENR_NONIDEA_A4', 'LEA_PSENR_NONIDEA_A5',
#        'LEA_PSENR_A2', 'LEA_PSENR_A3', 'LEA_PSENR_A4', 'LEA_PSENR_A5',
#        'LEA_PSELIG_ALL', 'LEA_PSELIG_IDEA', 'LEA_PSELIG_TITLEI',
#        'LEA_PSELIG_LOWINC', 'LEA_KG_IND', 'LEA_KG_FULLDAYFREE',
#        'LEA_KG_FULLDAYCOST', 'LEA_KG_PARTDAYFREE', 'LEA_KG_PARTDAYCOST',
#        'LEA_HSE_IND', 'LEA_HSEPART_HI_M', 'LEA_HSEPART_HI_F',
#        'LEA_HSEPART_AM_M', 'LEA_HSEPART_AM_F', 'LEA_HSEPART_AS_M',
#        'LEA_HSEPART_AS_F', 'LEA_HSEPART_HP_M', 'LEA_HSEPART_HP_F',
#        'LEA_HSEPART_BL_M', 'LEA_HSEPART_BL_F', 'LEA_HSEPART_WH_M',
#        'LEA_HSEPART_WH_F', 'LEA_HSEPART_TR_M', 'LEA_HSEPART_TR_F',
#        'TOT_HSEPART_M', 'TOT_HSEPART_F', 'LEA_HSEPART_LEP_M',
#        'LEA_HSEPART_LEP_F', 'LEA_HSEPART_IDEA_M', 'LEA_HSEPART_IDEA_F',
#        'LEA_DISTED_IND', 'LEA_DISTEDENR_HI_M', 'LEA_DISTEDENR_HI_F',
#        'LEA_DISTEDENR_AM_M', 'LEA_DISTEDENR_AM_F', 'LEA_DISTEDENR_AS_M',
#        'LEA_DISTEDENR_AS_F', 'LEA_DISTEDENR_HP_M', 'LEA_DISTEDENR_HP_F',
#        'LEA_DISTEDENR_BL_M', 'LEA_DISTEDENR_BL_F', 'LEA_DISTEDENR_WH_M',
#        'LEA_DISTEDENR_WH_F', 'LEA_DISTEDENR_TR_M', 'LEA_DISTEDENR_TR_F',
#        'TOT_DISTEDENR_M', 'TOT_DISTEDENR_F', 'LEA_DISTEDENR_LEP_M',
#        'LEA_DISTEDENR_LEP_F', 'LEA_DISTEDENR_IDEA_M', 'LEA_DISTEDENR_IDEA_F'],
#       dtype='object')

# %%
ax= sns.countplot(x='LEA_ECE_IND',data=df, palette='hls')
plt.show()

# %%
perc = 10.0
min_count =  int(((100-perc)/100)*df.shape[0] + 1)
mod_df = df.dropna( axis=1, 
                thresh=min_count)

mod_df= mod_df.select_dtypes(include=np.number)

print(mod_df)
# Out:
#          LEAID  COUNTY_NO  NUM_SCHS  NUM_CHRTS     IEP     TOTALREV  \
# 0       100002       1073         0        0.0    49.0          NaN
# 1       100005       1095         6        0.0   407.0   56909000.0
# 2       100006       1095        15        0.0   790.0   59036000.0
# 3       100007       1073        17        0.0  1291.0  179516000.0
# 4       100008       1089        11        0.0  1172.0  119390000.0
# ...        ...        ...       ...        ...     ...          ...
# 16724  5680250      56039         1        0.0     NaN          NaN
# 16725  5680251      56021         2        0.0     NaN          NaN
# 16726  5680252      56005         1        0.0     NaN          NaN
# 16727  5680254      56013         1        0.0    23.0          NaN
# 16728  5680255      32005         1        0.0     NaN          NaN
#
#           TOTALEXP  TOTALREVPP  TOTALEXPPP   MEMBER  ...  LEA_ENR  \
# 0              NaN         NaN         NaN      NaN  ...      280
# 1       50832000.0     10232.0      9139.0   5562.0  ...     5445
# 2       61817000.0     10427.0     10918.0   5662.0  ...     5698
# 3      178534000.0     12798.0     12728.0  14027.0  ...    14372
# 4      116231000.0     11089.0     10795.0  10767.0  ...    10810
# ...            ...         ...         ...      ...  ...      ...
# 16724          NaN         NaN         NaN     44.0  ...       48
# 16725          NaN         0.0         NaN     98.0  ...      162
# 16726          NaN         0.0         NaN     34.0  ...       34
# 16727          NaN         0.0         NaN    245.0  ...      243
# 16728          NaN         0.0         NaN     12.0  ...       31
#
#        LEA_ENR_NONLEAFAC  LEA_SCHOOLS  LEA_DESEGPLAN  LEA_HBPOLICY_IND  \
# 0                      0            3              0                 1
# 1                      0            6              0                 1
# 2                      0           13              0                 1
# 3                      0           16              1                 1
# 4                      0           11              0                 1
# ...                  ...          ...            ...               ...
# 16724                  0            3              0                 1
# 16725                  0            2              0                 1
# 16726                 28            1              0                 1
# 16727                  0            1              0                 1
# 16728                  0            1              0                 1
#
#        LEA_ECE_IND  LEA_PS_IND  LEA_KG_IND  LEA_HSE_IND  LEA_DISTED_IND
# 0                0           0           0            1               0
# 1                1           1           1            0               1
# 2                0           1           1            0               1
# 3                0           1           1            0               1
# 4                0           1           1            0               1
# ...            ...         ...         ...          ...             ...
# 16724            0           0           0            0               0
# 16725            0           0           0            1               0
# 16726            0           0           0            0               0
# 16727            0           0           1            0               1
# 16728            0           0           0            1               0
#
# [16729 rows x 27 columns]

# %%
mod_df = mod_df.dropna()
mod_df
X= mod_df.drop(columns=['LEA_ECE_IND', 'LEAID', 'COUNTY_NO'])
X
# Out:
#        NUM_SCHS  NUM_CHRTS     IEP     TOTALREV     TOTALEXP  TOTALREVPP  \
# 1             6        0.0   407.0   56909000.0   50832000.0     10232.0
# 2            15        0.0   790.0   59036000.0   61817000.0     10427.0
# 3            17        0.0  1291.0  179516000.0  178534000.0     12798.0
# 4            11        0.0  1172.0  119390000.0  116231000.0     11089.0
# 6             4        0.0   279.0   20007000.0   20693000.0     10135.0
# ...         ...        ...     ...          ...          ...         ...
# 16718        11        0.0   444.0   51564000.0   47405000.0     19787.0
# 16719         1        0.0    15.0    3515000.0    3274000.0     34461.0
# 16720         9        0.0   289.0   76124000.0   74341000.0     26598.0
# 16721         3        0.0    36.0    6657000.0    6384000.0     26209.0
# 16722         5        0.0   188.0   25414000.0   24575000.0     19948.0
#
#        TOTALEXPPP   MEMBER  AS_PI      HI  ...  CJJ  LEA_ENR  \
# 1          9139.0   5562.0   27.0  2709.0  ...    0     5445
# 2         10918.0   5662.0   20.0  1281.0  ...    0     5698
# 3         12728.0  14027.0  952.0  1095.0  ...    0    14372
# 4         10795.0  10767.0  907.0   511.0  ...    1    10810
# 6         10483.0   1974.0   19.0   261.0  ...    0     2027
# ...           ...      ...    ...     ...  ...  ...      ...
# 16718     18191.0   2606.0    4.0   409.0  ...    1     2607
# 16719     32098.0    102.0    1.0     0.0  ...    0      101
# 16720     25975.0   2862.0   59.0   879.0  ...    0     2871
# 16721     25134.0    254.0    0.0     6.0  ...    0      256
# 16722     19290.0   1274.0    2.0   333.0  ...    0     1284
#
#        LEA_ENR_NONLEAFAC  LEA_SCHOOLS  LEA_DESEGPLAN  LEA_HBPOLICY_IND  \
# 1                      0            6              0                 1
# 2                      0           13              0                 1
# 3                      0           16              1                 1
# 4                      0           11              0                 1
# 6                      0            4              1                 1
# ...                  ...          ...            ...               ...
# 16718                 21           11              0                 1
# 16719                  0            1              0                 1
# 16720                  0            9              0                 1
# 16721                  0            3              0                 1
# 16722                  0            5              0                 1
#
#        LEA_PS_IND  LEA_KG_IND  LEA_HSE_IND  LEA_DISTED_IND
# 1               1           1            0               1
# 2               1           1            0               1
# 3               1           1            0               1
# 4               1           1            0               1
# 6               1           1            1               1
# ...           ...         ...          ...             ...
# 16718           0           1            0               1
# 16719           1           1            0               1
# 16720           0           1            0               0
# 16721           0           1            0               0
# 16722           0           1            0               1
#
# [12599 rows x 24 columns]

# %%
y= mod_df['LEA_ECE_IND']
y
# Out:
# 1        1
# 2        0
# 3        0
# 4        0
# 6        0
#         ..
# 16718    0
# 16719    1
# 16720    0
# 16721    0
# 16722    0
# Name: LEA_ECE_IND, Length: 12599, dtype: int64

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /Applications/anaconda3/lib/python3.9/site-packages (0.9.1)
# Requirement already satisfied: joblib>=1.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /Applications/anaconda3/lib/python3.9/site-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.17.3 in /Applications/anaconda3/lib/python3.9/site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Applications/anaconda3/lib/python3.9/site-packages (from imbalanced-learn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from imbalanced-learn) (2.2.0)

# %%
import imblearn
from imblearn import over_sampling
from imblearn.over_sampling import SMOTE
from sklearn import metrics
from sklearn.model_selection import train_test_split

oversample = SMOTE()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
columns = X_train.columns

os_data_X,os_data_y=oversample.fit_resample(X_train, y_train)
os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
os_data_y= pd.DataFrame(data=os_data_y,columns=['LEA_ECE_IND'])

# we can Check the numbers of our data
print("Length of oversampled data is ",len(os_data_X))
print("Number of no subscription in oversampled data",len(os_data_y[os_data_y['LEA_ECE_IND']==0]))
print("Number of subscription",len(os_data_y[os_data_y['LEA_ECE_IND']==1]))
print("Proportion of no subscription data in oversampled data is ",len(os_data_y[os_data_y['LEA_ECE_IND']==0])/len(os_data_X))
print("Proportion of subscription data in oversampled data is ",len(os_data_y[os_data_y['LEA_ECE_IND']==1])/len(os_data_X))
# Out:
# length of oversampled data is  14606
# Number of no subscription in oversampled data 7303
# Number of subscription 7303
# Proportion of no subscription data in oversampled data is  0.5
# Proportion of subscription data in oversampled data is  0.5

# %%
X= os_data_X
print(X)
y= os_data_y['LEA_ECE_IND']
mod_df= pd.concat([X, y], axis=1, join='inner')
print(mod_df)
# Out:
#        NUM_SCHS   NUM_CHRTS           IEP      TOTALREV      TOTALEXP  \
# 0             3    3.000000     47.000000  4.754000e+06  4.546000e+06
# 1             5    0.000000    486.000000  5.025600e+07  4.774000e+07
# 2             1    1.000000     12.000000  2.370000e+06  2.694000e+06
# 3             8    0.000000    424.000000  4.086500e+07  5.344900e+07
# 4            16    2.000000    974.000000  5.627500e+07  5.409500e+07
# ...         ...         ...           ...           ...           ...
# 14601         3    0.000000    106.597924  8.638413e+06  8.490565e+06
# 14602         8    1.439882    362.549046  4.644279e+07  4.248460e+07
# 14603         3    0.000000     37.265271  3.910976e+06  4.211619e+06
# 14604         5    0.000000    304.834219  4.782205e+07  5.803799e+07
# 14605       853  234.625421  74215.664041  8.494378e+09  8.173016e+09
#
#          TOTALREVPP    TOTALEXPPP         MEMBER         AS_PI             HI  \
# 0      15286.000000  14617.000000     311.000000      2.000000       7.000000
# 1      20175.000000  19165.000000    2491.000000     93.000000      79.000000
# 2      15000.000000  17051.000000     158.000000      1.000000      26.000000
# 3      14077.000000  18412.000000    2903.000000     49.000000     889.000000
# 4      10092.000000   9701.000000    5576.000000     24.000000     674.000000
# ...             ...           ...            ...           ...            ...
# 14601  14769.383927  14531.688218     609.674389      3.239132      15.282603
# 14602  15628.969888  14301.993236    3145.990872     60.760266     891.175323
# 14603  15095.693311  16094.931486     276.108195      0.000000     101.697199
# 14604  14768.364845  18072.906846    3316.609937     37.430688     114.586594
# 14605  14998.984860  14525.487207  540935.001661  29066.281383  375735.469155
#
#        ...  CJJ  LEA_ENR  LEA_ENR_NONLEAFAC  LEA_SCHOOLS  LEA_DESEGPLAN  \
# 0      ...    0      309                  0            3              0
# 1      ...    0     2490                 32            5              0
# 2      ...    0      162                  1            1              0
# 3      ...    0     2740                  0            8              0
# 4      ...    0     5576                107           14              0
# ...    ...  ...      ...                ...          ...            ...
# 14601  ...    0      620                  0            3              0
# 14602  ...    0     2874                  0            6              0
# 14603  ...    0      279                  0            1              0
# 14604  ...    0     3398                  0            5              0
# 14605  ...    1   456373               3601          877              0
#
#        LEA_HBPOLICY_IND  LEA_PS_IND  LEA_KG_IND  LEA_HSE_IND  LEA_DISTED_IND
# 0                     1           1           1            0               1
# 1                     1           1           1            0               0
# 2                     1           0           1            0               0
# 3                     1           1           1            0               1
# 4                     1           1           1            0               1
# ...                 ...         ...         ...          ...             ...
# 14601                 1           1           1            0               0
# 14602                 1           1           1            0               0
# 14603                 1           0           1            0               1
# 14604                 1           1           1            0               0
# 14605                 1           1           1            1               1
#
# [14606 rows x 24 columns]
#        NUM_SCHS   NUM_CHRTS           IEP      TOTALREV      TOTALEXP  \
# 0             3    3.000000     47.000000  4.754000e+06  4.546000e+06
# 1             5    0.000000    486.000000  5.025600e+07  4.774000e+07
# 2             1    1.000000     12.000000  2.370000e+06  2.694000e+06
# 3             8    0.000000    424.000000  4.086500e+07  5.344900e+07
# 4            16    2.000000    974.000000  5.627500e+07  5.409500e+07
# ...         ...         ...           ...           ...           ...
# 14601         3    0.000000    106.597924  8.638413e+06  8.490565e+06
# 14602         8    1.439882    362.549046  4.644279e+07  4.248460e+07
# 14603         3    0.000000     37.265271  3.910976e+06  4.211619e+06
# 14604         5    0.000000    304.834219  4.782205e+07  5.803799e+07
# 14605       853  234.625421  74215.664041  8.494378e+09  8.173016e+09
#
#          TOTALREVPP    TOTALEXPPP         MEMBER         AS_PI             HI  \
# 0      15286.000000  14617.000000     311.000000      2.000000       7.000000
# 1      20175.000000  19165.000000    2491.000000     93.000000      79.000000
# 2      15000.000000  17051.000000     158.000000      1.000000      26.000000
# 3      14077.000000  18412.000000    2903.000000     49.000000     889.000000
# 4      10092.000000   9701.000000    5576.000000     24.000000     674.000000
# ...             ...           ...            ...           ...            ...
# 14601  14769.383927  14531.688218     609.674389      3.239132      15.282603
# 14602  15628.969888  14301.993236    3145.990872     60.760266     891.175323
# 14603  15095.693311  16094.931486     276.108195      0.000000     101.697199
# 14604  14768.364845  18072.906846    3316.609937     37.430688     114.586594
# 14605  14998.984860  14525.487207  540935.001661  29066.281383  375735.469155
#
#        ...  LEA_ENR  LEA_ENR_NONLEAFAC  LEA_SCHOOLS  LEA_DESEGPLAN  \
# 0      ...      309                  0            3              0
# 1      ...     2490                 32            5              0
# 2      ...      162                  1            1              0
# 3      ...     2740                  0            8              0
# 4      ...     5576                107           14              0
# ...    ...      ...                ...          ...            ...
# 14601  ...      620                  0            3              0
# 14602  ...     2874                  0            6              0
# 14603  ...      279                  0            1              0
# 14604  ...     3398                  0            5              0
# 14605  ...   456373               3601          877              0
#
#        LEA_HBPOLICY_IND  LEA_PS_IND  LEA_KG_IND  LEA_HSE_IND  LEA_DISTED_IND  \
# 0                     1           1           1            0               1
# 1                     1           1           1            0               0
# 2                     1           0           1            0               0
# 3                     1           1           1            0               1
# 4                     1           1           1            0               1
# ...                 ...         ...         ...          ...             ...
# 14601                 1           1           1            0               0
# 14602                 1           1           1            0               0
# 14603                 1           0           1            0               1
# 14604                 1           1           1            0               0
# 14605                 1           1           1            1               1
#
#        LEA_ECE_IND
# 0                0
# 1                0
# 2                0
# 3                1
# 4                0
# ...            ...
# 14601            1
# 14602            1
# 14603            1
# 14604            1
# 14605            1
#
# [14606 rows x 25 columns]

# %%
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm

logit_model_2=sm.Logit(y,X)
result_2=logit_model_2.fit()
print(result_2.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.561699
#          Iterations 7
#                           Results: Logit
# ==================================================================
# Model:               Logit            Pseudo R-squared: 0.190
# Dependent Variable:  LEA_ECE_IND      AIC:              16456.3532
# Date:                2022-06-13 23:27 BIC:              16638.4937
# No. Observations:    14606            Log-Likelihood:   -8204.2
# Df Model:            23               LL-Null:          -10124.
# Df Residuals:        14582            LLR p-value:      0.0000
# Converged:           1.0000           Scale:            1.0000
# No. Iterations:      7.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# NUM_SCHS           0.2745   0.0229  11.9938 0.0000  0.2296  0.3193
# NUM_CHRTS         -0.1823   0.0172 -10.5699 0.0000 -0.2160 -0.1485
# IEP               -0.0007   0.0001  -6.1306 0.0000 -0.0009 -0.0005
# TOTALREV          -0.0000   0.0000  -5.3083 0.0000 -0.0000 -0.0000
# TOTALEXP           0.0000   0.0000   4.6014 0.0000  0.0000  0.0000
# TOTALREVPP         0.0000   0.0000   1.6677 0.0954 -0.0000  0.0000
# TOTALEXPPP        -0.0000   0.0000  -1.1112 0.2665 -0.0000  0.0000
# MEMBER            -0.0003   0.0003  -1.0821 0.2792 -0.0008  0.0002
# AS_PI              0.0001   0.0001   0.8141 0.4156 -0.0001  0.0002
# HI                 0.0004   0.0001   6.0746 0.0000  0.0003  0.0005
# BL                 0.0003   0.0001   4.4294 0.0000  0.0001  0.0004
# WH                 0.0003   0.0001   5.5621 0.0000  0.0002  0.0004
# TR                 0.0010   0.0002   5.8816 0.0000  0.0007  0.0014
# TOTETH            -0.0001   0.0003  -0.5312 0.5953 -0.0007  0.0004
# CJJ               -0.9027   0.0951  -9.4944 0.0000 -1.0890 -0.7163
# LEA_ENR            0.0001   0.0000   2.3588 0.0183  0.0000  0.0002
# LEA_ENR_NONLEAFAC -0.0000   0.0000  -0.4458 0.6557 -0.0001  0.0001
# LEA_SCHOOLS       -0.1539   0.0222  -6.9203 0.0000 -0.1975 -0.1103
# LEA_DESEGPLAN     -1.7280   0.1997  -8.6511 0.0000 -2.1195 -1.3365
# LEA_HBPOLICY_IND  -1.7164   0.0873 -19.6715 0.0000 -1.8874 -1.5454
# LEA_PS_IND         1.6979   0.0536  31.6966 0.0000  1.5929  1.8029
# LEA_KG_IND         0.1531   0.0867   1.7663 0.0773 -0.0168  0.3229
# LEA_HSE_IND       -0.6725   0.0812  -8.2862 0.0000 -0.8316 -0.5135
# LEA_DISTED_IND    -0.7805   0.0423 -18.4706 0.0000 -0.8633 -0.6976
# ==================================================================

# %%
from sklearn import linear_model
from sklearn.metrics import roc_auc_score

def auc(variables, target, mod_df):
    X = mod_df[variables]
    y = mod_df[target]
    logreg = linear_model.LogisticRegression()
    logreg.fit(X, y)
    predictions = logreg.predict_proba(X)[:,1]
    auc = roc_auc_score(y, predictions)
    return(auc)

# %%
new_cols = ["NUM_SCHS", 'NUM_CHRTS', 'IEP','CJJ','LEA_HBPOLICY_IND','LEA_PS_IND','LEA_DISTED_IND']
auc = auc(new_cols,["LEA_ECE_IND"],mod_df)
print(round(auc,2))
# Out:
# 0.77
# /Applications/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Applications/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
new_X =X[new_cols]

logit_model_2=sm.Logit(y,new_X)
result_2=logit_model_2.fit()
print(result_2.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.575148
#          Iterations 7
#                          Results: Logit
# =================================================================
# Model:              Logit            Pseudo R-squared: 0.170
# Dependent Variable: LEA_ECE_IND      AIC:              16815.2377
# Date:               2022-06-13 23:28 BIC:              16868.3620
# No. Observations:   14606            Log-Likelihood:   -8400.6
# Df Model:           6                LL-Null:          -10124.
# Df Residuals:       14599            LLR p-value:      0.0000
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     7.0000
# -----------------------------------------------------------------
#                   Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -----------------------------------------------------------------
# NUM_SCHS          0.1214   0.0071  17.0730 0.0000  0.1075  0.1353
# NUM_CHRTS        -0.1780   0.0135 -13.2069 0.0000 -0.2044 -0.1516
# IEP              -0.0007   0.0001  -9.4542 0.0000 -0.0008 -0.0005
# CJJ              -0.8820   0.0899  -9.8153 0.0000 -1.0581 -0.7059
# LEA_HBPOLICY_IND -1.5269   0.0463 -32.9514 0.0000 -1.6177 -1.4360
# LEA_PS_IND        1.7211   0.0510  33.7219 0.0000  1.6210  1.8211
# LEA_DISTED_IND   -0.8274   0.0413 -20.0242 0.0000 -0.9084 -0.7464
# =================================================================

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(new_X, y, test_size=0.25, random_state=0)

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print(y_pred)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Index(['NUM_SCHS', 'NUM_CHRTS', 'IEP', 'CJJ', 'LEA_HBPOLICY_IND', 'LEA_PS_IND',
#        'LEA_DISTED_IND'],
#       dtype='object')
# Index(['NUM_SCHS', 'NUM_CHRTS', 'IEP', 'CJJ', 'LEA_HBPOLICY_IND', 'LEA_PS_IND',
#        'LEA_DISTED_IND'],
#       dtype='object')
# [1 0 1 ... 0 0 1]
# Accuracy of logistic regression classifier on test set: 0.69
# /Applications/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)


group_names = ['True Neg','False Pos','False Neg','True Pos']

group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]

labels = np.asarray(labels).reshape(2,2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

ax.set_title('Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.61      0.66      1825
#            1       0.66      0.77      0.71      1827
#
#     accuracy                           0.69      3652
#    macro avg       0.70      0.69      0.69      3652
# weighted avg       0.70      0.69      0.69      3652

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
print(logit_roc_auc)
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
print(fpr)
print(tpr)
print(thresholds)

plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--') # Drawing 45 degree line
#plt.xlim([0.0, 1.0]) # 
#plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('Log_ROC_balanced')
plt.show()
# Out:
# 0.6902635505469705
# [0.         0.         0.         ... 0.99561644 0.99561644 1.        ]
# [0.00000000e+00 5.47345375e-04 4.92610837e-03 ... 9.99452655e-01
#  1.00000000e+00 1.00000000e+00]
# [2.         1.         0.99983166 ... 0.06350282 0.06266185 0.02273014]
